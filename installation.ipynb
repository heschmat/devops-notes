# %% [markdown]
# ## Docker

# %%
# Follow the instructions at: https://docs.docker.com/engine/install/ubuntu/
"""
# Add Docker's official GPG key:
sudo apt-get update
sudo apt-get install ca-certificates curl
sudo install -m 0755 -d /etc/apt/keyrings
sudo curl -fsSL https://download.docker.com/linux/ubuntu/gpg -o /etc/apt/keyrings/docker.asc
sudo chmod a+r /etc/apt/keyrings/docker.asc

# Add the repository to Apt sources:
echo \
  "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.asc] https://download.docker.com/linux/ubuntu \
  $(. /etc/os-release && echo "${UBUNTU_CODENAME:-$VERSION_CODENAME}") stable" | \
  sudo tee /etc/apt/sources.list.d/docker.list > /dev/null


sudo apt-get update

# install the latest version of the docker packages:
sudo apt-get install docker-ce docker-ce-cli containerd.io docker-buildx-plugin docker-compose-plugin -y

""";

# %%
"""
# Verify that the installation is successful by running the hello-world image:

sudo docker run hello-world
""";

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# However, the user doesn't have permission to access the Docker daemon via the Unix socket yet.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Using `sudo` is less than optimal.
# => Add the user to the docker group.

"""
$ sudo usermod -aG docker ubuntu

# Switch the shell session to the new `docker` group
$ newgrp docker

# If this doesn't work, simply logout and log back in.
# Now we should be able to access docker without sudo.

""";

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## kubectl

# %%
# Follow the instructions at: https://kubernetes.io/docs/tasks/tools/install-kubectl-linux/
"""
curl -LO "https://dl.k8s.io/release/$(curl -L -s https://dl.k8s.io/release/stable.txt)/bin/linux/amd64/kubectl"

curl -LO "https://dl.k8s.io/release/$(curl -L -s https://dl.k8s.io/release/stable.txt)/bin/linux/amd64/kubectl.sha256"

# Validate the kubectl binary against the checksum file:
echo "$(cat kubectl.sha256)  kubectl" | sha256sum --check
## kubectl: OK

# Install
sudo install -o root -g root -m 0755 kubectl /usr/local/bin/kubectl

""";

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# NOTE:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""
N.B. Client version must be compatible with your cluster's Server version.

Generally, kubectl works best when it's within one minor version (+/- 1) of the server version.

For example:
If your cluster is v1.32.x, your kubectl client should be v1.31.x, v1.32.x, or v1.33.x.
""";

# %%
# What's the error message?
"""
By default, kubectl looks for a config file at: ~/.kube/config

If this file is missing, incomplete, or pointing to localhost:8080 (which is not a real cluster),
we'll get the error we see above:

The connection to the server localhost:8080 was refused - did you specify the right host or port?

""";

# %% [markdown]
# ## eksctl

# %%
"""
# Download the latest eksctl release:
curl -O https://s3.us-west-2.amazonaws.com/amazon-eks/1.31.3/2024-12-12/bin/linux/arm64/kubectl
curl --silent --location "https://github.com/eksctl-io/eksctl/releases/latest/download/eksctl_$(uname -s)_amd64.tar.gz" -o eksctl.tar.gz

tar -xzf eksctl.tar.gz


# Move the binary
sudo mv eksctl /usr/local/bin


eksctl version
""";

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## KinD

# %%
# follow the instructions here:
# https://kind.sigs.k8s.io/docs/user/quick-start/

# for linux =>
"""
# check your machine's CPU architecture using
uname -m


# For AMD64 / x86_64
[ $(uname -m) = x86_64 ] && curl -Lo ./kind https://kind.sigs.k8s.io/dl/v0.29.0/kind-linux-amd64

# For ARM64
[ $(uname -m) = aarch64 ] && curl -Lo ./kind https://kind.sigs.k8s.io/dl/v0.29.0/kind-linux-arm64


chmod +x ./kind
sudo mv ./kind /usr/local/bin/kind
""";

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Terraform

# %%
# Follow the instructions:
# https://developer.hashicorp.com/terraform/tutorials/aws-get-started/install-cli

"""
sudo apt-get update && sudo apt-get install -y gnupg software-properties-common


wget -O- https://apt.releases.hashicorp.com/gpg | \
    gpg --dearmor | \
    sudo tee /usr/share/keyrings/hashicorp-archive-keyring.gpg > /dev/null

gpg --no-default-keyring \
--keyring /usr/share/keyrings/hashicorp-archive-keyring.gpg \
--fingerprint


# Add the official HashiCorp repository to your system.
echo "deb [signed-by=/usr/share/keyrings/hashicorp-archive-keyring.gpg] \
https://apt.releases.hashicorp.com $(lsb_release -cs) main" | \
sudo tee /etc/apt/sources.list.d/hashicorp.list


sudo apt update

# Install Terraform from the new repository.
sudo apt-get install terraform


$ terraform --version
Terraform v1.12.2
on linux_amd64

""";

# %% [markdown]
# ## Helm

# %%
"""
curl https://raw.githubusercontent.com/helm/helm/main/scripts/get-helm-3 | bash

helm version
"""
# Out:
# '\ncurl https://raw.githubusercontent.com/helm/helm/main/scripts/get-helm-3 | bash\n\nhelm version\n'

# %% [markdown]
# ![image.png](data:image/png;base64,...)
